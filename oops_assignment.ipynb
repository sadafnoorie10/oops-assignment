# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Q1) what are the five key concepts of object-oriented programming (OOP)?
#
# A1) The five key concepts of Object-Oriented Programming (OOP) are:
#
# 1. **Encapsulation**:
#    - Encapsulation is the practice of bundling the data (attributes) and methods (functions) that operate on the data into a single unit known as a class. It restricts direct access to some of the object's components, which can prevent the accidental modification of data. This is often achieved through access modifiers (e.g., public, private, protected).
#
# 2. **Abstraction**:
#    - Abstraction is the concept of hiding complex implementation details and showing only the essential features of the object. It allows programmers to focus on interactions at a higher level without worrying about the underlying complexity. This is often achieved through abstract classes and interfaces, which define methods without providing their implementations.
#
# 3. **Inheritance**:
#    - Inheritance is a mechanism by which one class (the child or subclass) can inherit attributes and methods from another class (the parent or superclass). This promotes code reusability and establishes a hierarchical relationship between classes. The subclass can override or extend the functionalities of the parent class.
#
# 4. **Polymorphism**:
#    - Polymorphism allows objects to be treated as instances of their parent class, even if they are actually instances of a subclass. This means that a single function or method can work in different ways depending on the object it is operating on. Polymorphism can be achieved through method overriding (runtime polymorphism) and method overloading (compile-time polymorphism).
#
# 5. **Classes and Objects**:
#    - Classes are blueprints for creating objects, defining attributes and methods. An object is an instance of a class that encapsulates data and behavior. Classes define the structure and capabilities of the objects, while objects are the actual entities created based on these definitions.
#
# ### Summary:
# These five concepts work together to create a programming paradigm that is modular, reusable, and easier to manage. By organizing code into classes and objects, OOP helps in building complex systems while keeping code clean and maintainable.

# %% [markdown]
# Q2) write a python class for a 'Car' with attributes for 'make', 'model', and 'year'. Include a method to display the car's information.
#
# A2) Here’s a Python class for a `Car` with attributes for `make`, `model`, and `year`, along with a method to display the car's information:
#
# ```python
# class Car:
#     def __init__(self, make, model, year):
#         """Initialize the Car object with make, model, and year."""
#         self.make = make
#         self.model = model
#         self.year = year
#
#     def display_info(self):
#         """Display the car's information."""
#         info = f"Car Information:\nMake: {self.make}\nModel: {self.model}\nYear: {self.year}"
#         print(info)
#
# # Example usage
# my_car = Car("Toyota", "Camry", 2020)
# my_car.display_info()
# ```
#
# ### Explanation:
# 1. **Class Definition**:
#    - The `Car` class is defined with an `__init__` method, which is a constructor that initializes the attributes `make`, `model`, and `year`.
#
# 2. **Attributes**:
#    - `self.make`, `self.model`, and `self.year` are instance variables that store the values passed to the constructor.
#
# 3. **Method**:
#    - The `display_info` method formats and prints the car's information.
#
# 4. **Example Usage**:
#    - An instance of the `Car` class is created with specific values, and the `display_info` method is called to print the car's details.
#
# ### Example Output:
# When you run the above code, the output will be:
# ```
# Car Information:
# Make: Toyota
# Model: Camry
# Year: 2020
# ```

# %% [markdown]
# Q3) Explain the difference between instance methods and class methods. Provide an example of each.
#
# A3) In Python, **instance methods** and **class methods** are both types of methods that belong to classes, but they have different purposes and behaviors.
#
# ### Instance Methods
#
# - **Definition**: Instance methods are the most common type of methods in Python classes. They operate on an instance of the class (an object) and can access and modify the object's attributes.
# - **Self Parameter**: Instance methods take the instance (referred to as `self`) as their first parameter, which allows them to access the instance's attributes and other methods.
#
# **Example of an Instance Method**:
# ```python
# class Dog:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def bark(self):
#         return f"{self.name} says Woof!"
#
# # Creating an instance of Dog
# my_dog = Dog("Buddy", 3)
# print(my_dog.bark())  # Output: Buddy says Woof!
# ```
#
# ### Class Methods
#
# - **Definition**: Class methods are methods that belong to the class itself rather than any particular instance. They can be called on the class and do not require an instance to be created.
# - **Cls Parameter**: Class methods take a class reference (referred to as `cls`) as their first parameter, allowing them to access class-level attributes and other class methods.
# - **Decorator**: Class methods are defined using the `@classmethod` decorator.
#
# **Example of a Class Method**:
# ```python
# class Dog:
#     species = "Canis lupus familiaris"  # Class attribute
#
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     @classmethod
#     def get_species(cls):
#         return cls.species
#
# # Accessing the class method
# print(Dog.get_species())  # Output: Canis lupus familiaris
# ```
#
# ### Key Differences
#
# | Feature                | Instance Method                               | Class Method                          |
# |------------------------|----------------------------------------------|--------------------------------------|
# | Definition             | Operates on an instance of the class        | Operates on the class itself        |
# | First Parameter        | `self` (instance)                           | `cls` (class)                       |
# | Access                 | Can access and modify instance attributes    | Can access and modify class attributes|
# | Invocation             | Called on an instance (e.g., `my_dog.bark()`) | Called on the class (e.g., `Dog.get_species()`) |
# | Use Case               | For behaviors that require instance data     | For methods related to the class or shared data across instances |
#
# ### Summary
# Instance methods are used for operations specific to an object, while class methods are used for operations that pertain to the class as a whole. Understanding the difference helps in designing classes more effectively.

# %% [markdown]
# Q4) How does python implement method overloading? Give example.
#
# A4) Python does not support method overloading in the traditional sense, as seen in some other programming languages like Java or C++. Instead, Python allows only one method with a given name in a class. However, you can achieve similar functionality using default parameters, variable-length arguments, or type checking within a single method.
#
# ### Example of Method Overloading Using Default Parameters
#
# You can use default parameters to simulate method overloading. Here's an example:
#
# ```python
# class MathOperations:
#     def add(self, a, b=0, c=0):
#         """Adds two or three numbers."""
#         return a + b + c
#
# # Example usage
# math_op = MathOperations()
#
# print(math_op.add(5))          # Output: 5 (5 + 0 + 0)
# print(math_op.add(5, 10))      # Output: 15 (5 + 10 + 0)
# print(math_op.add(5, 10, 15))  # Output: 30 (5 + 10 + 15)
# ```
#
# ### Example of Method Overloading Using *args
#
# Another way to implement method overloading is by using the `*args` parameter, which allows for a variable number of arguments.
#
# ```python
# class MathOperations:
#     def add(self, *args):
#         """Adds any number of numbers."""
#         return sum(args)
#
# # Example usage
# math_op = MathOperations()
#
# print(math_op.add(5))               # Output: 5
# print(math_op.add(5, 10))           # Output: 15
# print(math_op.add(5, 10, 15))       # Output: 30
# print(math_op.add(1, 2, 3, 4, 5))   # Output: 15
# ```
#
# ### Example of Method Overloading Using Type Checking
#
# You can also implement behavior based on argument types by checking the types within a single method.
#
# ```python
# class MathOperations:
#     def multiply(self, a, b):
#         """Multiplies two numbers, or two strings if they are both strings."""
#         if isinstance(a, str) and isinstance(b, str):
#             return a * len(b)  # Repeat string a, len(b) times
#         return a * b
#
# # Example usage
# math_op = MathOperations()
#
# print(math_op.multiply(5, 10))          # Output: 50 (5 * 10)
# print(math_op.multiply("Hello ", 3))    # Output: Hello Hello Hello
# ```
#
# ### Summary
#
# - **Single Method Definition**: In Python, you define a method once and handle different cases inside that method using default parameters, `*args`, or type checking.
# - **Flexibility**: This allows for more flexible method definitions but requires additional logic within the method to handle the different types or numbers of arguments.
#
# Python's approach to method overloading allows for a clean and readable design, making it easier to manage method behaviors without cluttering the class with multiple definitions.

# %% [markdown]
# Q5) what are the three types of access modifiers in python? How are they denoted?
#
# A5) In Python, access modifiers are used to define the accessibility of class members (attributes and methods). There are three main types of access modifiers:
#
# 1. **Public**:
#    - **Definition**: Public members are accessible from outside the class. There are no restrictions on their access.
#    - **Denotation**: Public members are defined without any prefix.
#    - **Example**:
#      ```python
#      class MyClass:
#          def __init__(self):
#              self.public_attribute = "I am public!"
#
#      obj = MyClass()
#      print(obj.public_attribute)  # Output: I am public!
#      ```
#
# 2. **Protected**:
#    - **Definition**: Protected members are intended to be accessible within the class and its subclasses (derived classes). They are not meant to be accessed from outside these classes.
#    - **Denotation**: Protected members are denoted by a single underscore (`_`) prefix.
#    - **Example**:
#      ```python
#      class MyClass:
#          def __init__(self):
#              self._protected_attribute = "I am protected!"
#
#      class DerivedClass(MyClass):
#          def show(self):
#              return self._protected_attribute  # Accessible in subclass
#
#      obj = DerivedClass()
#      print(obj.show())  # Output: I am protected!
#      ```
#
# 3. **Private**:
#    - **Definition**: Private members are only accessible within the class in which they are defined. They cannot be accessed from outside the class or even by subclasses.
#    - **Denotation**: Private members are denoted by a double underscore (`__`) prefix.
#    - **Example**:
#      ```python
#      class MyClass:
#          def __init__(self):
#              self.__private_attribute = "I am private!"
#
#          def get_private_attribute(self):
#              return self.__private_attribute  # Accessible within the class
#
#      obj = MyClass()
#      # print(obj.__private_attribute)  # Raises AttributeError
#      print(obj.get_private_attribute())  # Output: I am private!
#      ```
#
# ### Summary of Access Modifiers
#
# | Modifier Type | Denotation           | Accessibility                                        |
# |---------------|----------------------|-----------------------------------------------------|
# | Public        | No prefix            | Accessible from anywhere                             |
# | Protected     | Single underscore `_` | Accessible within the class and subclasses          |
# | Private       | Double underscore `__`| Accessible only within the class itself             |
#
# These access modifiers help in encapsulating data and controlling access to class members, enhancing data security and integrity in object-oriented programming.

# %% [markdown]
# Q6) Describe the fives types of inheritance in python. Provide a simple example pf multiple inheritance.
#
# A6) In Python, inheritance allows a class (called a derived class or child class) to inherit attributes and methods from another class (called a base class or parent class). There are five main types of inheritance in Python:
#
# ### 1. Single Inheritance
# - **Definition**: In single inheritance, a child class inherits from a single parent class.
# - **Example**:
#     ```python
#     class Parent:
#         def speak(self):
#             return "I am the parent."
#
#     class Child(Parent):
#         pass
#
#     c = Child()
#     print(c.speak())  # Output: I am the parent.
#     ```
#
# ### 2. Multiple Inheritance
# - **Definition**: In multiple inheritance, a child class can inherit from more than one parent class.
# - **Example**:
#     ```python
#     class Parent1:
#         def speak(self):
#             return "I am Parent 1."
#
#     class Parent2:
#         def greet(self):
#             return "Hello from Parent 2."
#
#     class Child(Parent1, Parent2):
#         pass
#
#     c = Child()
#     print(c.speak())  # Output: I am Parent 1.
#     print(c.greet())  # Output: Hello from Parent 2.
#     ```
#
# ### 3. Multilevel Inheritance
# - **Definition**: In multilevel inheritance, a child class inherits from a parent class, and another child class inherits from that child class.
# - **Example**:
#     ```python
#     class Grandparent:
#         def speak(self):
#             return "I am the grandparent."
#
#     class Parent(Grandparent):
#         def greet(self):
#             return "I am the parent."
#
#     class Child(Parent):
#         pass
#
#     c = Child()
#     print(c.speak())  # Output: I am the grandparent.
#     print(c.greet())  # Output: I am the parent.
#     ```
#
# ### 4. Hierarchical Inheritance
# - **Definition**: In hierarchical inheritance, multiple child classes inherit from the same parent class.
# - **Example**:
#     ```python
#     class Parent:
#         def speak(self):
#             return "I am the parent."
#
#     class Child1(Parent):
#         pass
#
#     class Child2(Parent):
#         pass
#
#     c1 = Child1()
#     c2 = Child2()
#     print(c1.speak())  # Output: I am the parent.
#     print(c2.speak())  # Output: I am the parent.
#     ```
#
# ### 5. Hybrid Inheritance
# - **Definition**: Hybrid inheritance is a combination of two or more types of inheritance. This can include multiple inheritance, multilevel inheritance, and hierarchical inheritance.
# - **Example**:
#     ```python
#     class Base:
#         def speak(self):
#             return "I am the base class."
#
#     class Parent1(Base):
#         def greet(self):
#             return "Hello from Parent 1."
#
#     class Parent2(Base):
#         def welcome(self):
#             return "Welcome from Parent 2."
#
#     class Child(Parent1, Parent2):
#         pass
#
#     c = Child()
#     print(c.speak())   # Output: I am the base class.
#     print(c.greet())   # Output: Hello from Parent 1.
#     print(c.welcome())  # Output: Welcome from Parent 2.
#     ```
#
# ### Summary
# - **Single Inheritance**: One child, one parent.
# - **Multiple Inheritance**: One child, multiple parents.
# - **Multilevel Inheritance**: Child inherits from a parent, which itself is a child of another parent.
# - **Hierarchical Inheritance**: Multiple children inherit from the same parent.
# - **Hybrid Inheritance**: A combination of different types of inheritance.
#
# Multiple inheritance allows a class to inherit behaviors and attributes from multiple classes, providing flexibility in design but also requiring careful management to avoid conflicts (e.g., the diamond problem).

# %% [markdown]
# Q7) what is the Method Resolution Order (MRO) in python? How can you retrieve it programmatically?
#
# A7) ### Method Resolution Order (MRO)
#
# **Method Resolution Order (MRO)** is a crucial concept in Python, particularly in the context of multiple inheritance. It defines the order in which base classes are searched when executing a method or accessing an attribute. The MRO determines which method will be invoked when a method is called on an instance of a class that inherits from multiple classes.
#
# #### Key Points:
# - The MRO follows the **C3 linearization** algorithm, which ensures a consistent and predictable order.
# - It allows for resolving method conflicts in a systematic way.
# - In Python, you can retrieve the MRO for a class using the `mro()` method or the `__mro__` attribute.
#
# ### Example of MRO
#
# Here’s an example illustrating MRO in a multiple inheritance scenario:
#
# ```python
# class A:
#     def speak(self):
#         return "A"
#
# class B(A):
#     def speak(self):
#         return "B"
#
# class C(A):
#     def speak(self):
#         return "C"
#
# class D(B, C):
#     pass
#
# # Create an instance of D
# d = D()
# print(d.speak())  # Output: B
# ```
#
# In this example:
# - Class `D` inherits from both `B` and `C`.
# - When `d.speak()` is called, Python looks for the `speak` method in the order defined by the MRO. Since `B` comes before `C` in the MRO, the method from `B` is invoked, returning "B".
#
# ### Retrieving the MRO Programmatically
#
# You can retrieve the MRO for a class using the following methods:
#
# 1. **Using the `mro()` Method**:
#    ```python
#    print(D.mro())
#    ```
#
# 2. **Using the `__mro__` Attribute**:
#    ```python
#    print(D.__mro__)
#    ```
#
# Both of these methods will return a list (or tuple) of classes in the order that Python will search when looking for methods or attributes.
#
# ### Example Code to Retrieve MRO
#
# Here’s how you can use it in code:
#
# ```python
# class A:
#     pass
#
# class B(A):
#     pass
#
# class C(A):
#     pass
#
# class D(B, C):
#     pass
#
# # Retrieve MRO using mro() method
# print(D.mro())         # Output: [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]
#
# # Retrieve MRO using __mro__ attribute
# print(D.__mro__)      # Output: (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)
# ```
#
# ### Summary
#
# - **MRO** determines the order in which classes are searched for methods and attributes.
# - It is particularly important in multiple inheritance scenarios to avoid ambiguity and ensure consistent behavior.
# - You can programmatically retrieve the MRO using the `mro()` method or the `__mro__` attribute, providing insight into the inheritance hierarchy of your classes.

# %% [markdown]
# Q8) Create an abstract base 'shape' with an abstract method 'area()'. Then create two subclasses 'circle' and 'rectangle' that implement the 'area()' method.
#
# A8) To create an abstract base class in Python, you can use the `abc` module, which provides the necessary tools to define abstract classes and methods. Here’s how you can create an abstract base class called `Shape` with an abstract method `area()`, and then implement subclasses `Circle` and `Rectangle` that define the `area()` method.
#
# ### Code Example
#
# ```python
# from abc import ABC, abstractmethod
# import math
#
# # Abstract Base Class
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
# # Subclass for Circle
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return math.pi * (self.radius ** 2)
#
# # Subclass for Rectangle
# class Rectangle(Shape):
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
#
# # Example usage
# if __name__ == "__main__":
#     # Create a Circle object
#     circle = Circle(radius=5)
#     print(f"Area of Circle: {circle.area():.2f}")  # Output: Area of Circle: 78.54
#
#     # Create a Rectangle object
#     rectangle = Rectangle(width=4, height=6)
#     print(f"Area of Rectangle: {rectangle.area()}")  # Output: Area of Rectangle: 24
# ```
#
# ### Explanation
#
# 1. **Abstract Base Class (`Shape`)**:
#    - The `Shape` class is defined as an abstract base class by inheriting from `ABC`.
#    - The `area()` method is marked as an abstract method using the `@abstractmethod` decorator, meaning that any subclass must implement this method.
#
# 2. **Subclasses (`Circle` and `Rectangle`)**:
#    - The `Circle` class has an `__init__` method that initializes the `radius` attribute and implements the `area()` method, which calculates the area of a circle using the formula \( \pi r^2 \).
#    - The `Rectangle` class has an `__init__` method that initializes the `width` and `height` attributes and implements the `area()` method, which calculates the area using the formula \( \text{width} \times \text{height} \).
#
# 3. **Example Usage**:
#    - In the `if __name__ == "__main__":` block, instances of `Circle` and `Rectangle` are created, and their `area()` methods are called to print the areas.
#
# ### Output
# When you run the code, you should see:
# ```
# Area of Circle: 78.54
# Area of Rectangle: 24
# ```
#
# This example demonstrates the use of abstract classes and methods in Python, allowing you to define a common interface for different shapes while ensuring that each specific shape implements its own area calculation.

# %% [markdown]
# Q9) Demonstrate polymorphism by creating a function that can work with different shape objects to calculate and print their areas.
#
# A9) Polymorphism in Python allows objects of different classes to be treated as objects of a common superclass. This is particularly useful when you have a common interface (like an abstract method) that different classes implement in their own way.
#
# In the context of the previous example with shapes, we can create a function that accepts any object derived from the `Shape` class and calculates its area. Here's how you can demonstrate polymorphism by creating such a function:
#
# ### Code Example
#
# ```python
# from abc import ABC, abstractmethod
# import math
#
# # Abstract Base Class
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
# # Subclass for Circle
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return math.pi * (self.radius ** 2)
#
# # Subclass for Rectangle
# class Rectangle(Shape):
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
#
# # Function to calculate and print area of any shape
# def print_area(shape: Shape):
#     print(f"Area: {shape.area():.2f}")
#
# # Example usage
# if __name__ == "__main__":
#     # Create instances of Circle and Rectangle
#     circle = Circle(radius=5)
#     rectangle = Rectangle(width=4, height=6)
#
#     # Demonstrate polymorphism
#     print_area(circle)     # Output: Area: 78.54
#     print_area(rectangle)  # Output: Area: 24.00
# ```
#
# ### Explanation
#
# 1. **Abstract Base Class (`Shape`)**:
#    - The `Shape` class remains the same, with an abstract method `area()` that subclasses must implement.
#
# 2. **Subclasses (`Circle` and `Rectangle`)**:
#    - The `Circle` and `Rectangle` classes also remain unchanged, implementing their respective `area()` methods.
#
# 3. **Polymorphic Function (`print_area`)**:
#    - The function `print_area()` takes an argument `shape` that is expected to be an instance of the `Shape` class (or any subclass thereof).
#    - Inside the function, it calls the `area()` method on the `shape` object, demonstrating polymorphism since the same function can operate on different types of shapes.
#
# 4. **Example Usage**:
#    - Instances of `Circle` and `Rectangle` are created.
#    - The `print_area()` function is called with each shape object, and it correctly calculates and prints the area for both shapes.
#
# ### Output
# When you run the code, you should see:
# ```
# Area: 78.54
# Area: 24.00
# ```
#
# This example illustrates polymorphism by allowing the `print_area()` function to work with different types of shape objects, calling their specific implementations of the `area()` method.

# %% [markdown]
# Q10) Implement encapsulation in a 'BankAccount' class with private attributes for 'balance' and 'account_number'. Include methods for deposit, withdrawal, and balance inquiry.
#
# A10) Encapsulation is a fundamental principle of object-oriented programming that restricts direct access to certain attributes and methods of a class. This helps in protecting the integrity of the object's state and promotes a controlled interface to interact with the object's data.
#
# Here’s how you can implement encapsulation in a `BankAccount` class with private attributes for `balance` and `account_number`. The class will also include methods for depositing, withdrawing, and inquiring the balance.
#
# ### Code Example
#
# ```python
# class BankAccount:
#     def __init__(self, account_number, initial_balance=0):
#         self.__account_number = account_number  # Private attribute
#         self.__balance = initial_balance          # Private attribute
#
#     def deposit(self, amount):
#         if amount > 0:
#             self.__balance += amount
#             print(f"Deposited: ${amount:.2f}. New balance: ${self.__balance:.2f}.")
#         else:
#             print("Deposit amount must be positive.")
#
#     def withdraw(self, amount):
#         if amount > 0:
#             if amount <= self.__balance:
#                 self.__balance -= amount
#                 print(f"Withdrew: ${amount:.2f}. New balance: ${self.__balance:.2f}.")
#             else:
#                 print("Insufficient funds.")
#         else:
#             print("Withdrawal amount must be positive.")
#
#     def get_balance(self):
#         return self.__balance
#
#     def get_account_number(self):
#         return self.__account_number
#
# # Example usage
# if __name__ == "__main__":
#     # Create a BankAccount object
#     account = BankAccount(account_number="12345678", initial_balance=1000)
#
#     # Deposit money
#     account.deposit(500)  # Deposited: $500.00. New balance: $1500.00.
#
#     # Withdraw money
#     account.withdraw(200)  # Withdrew: $200.00. New balance: $1300.00.
#
#     # Check balance
#     print(f"Current balance: ${account.get_balance():.2f}")  # Current balance: $1300.00
#
#     # Check account number
#     print(f"Account Number: {account.get_account_number()}")  # Account Number: 12345678
#
#     # Attempt to withdraw more than the balance
#     account.withdraw(2000)  # Insufficient funds.
# ```
#
# ### Explanation
#
# 1. **Private Attributes**:
#    - The attributes `__account_number` and `__balance` are defined with a double underscore prefix, making them private. This prevents direct access from outside the class.
#
# 2. **Methods**:
#    - **`deposit(amount)`**: Adds a specified amount to the balance if the amount is positive. It prints the updated balance.
#    - **`withdraw(amount)`**: Deducts a specified amount from the balance if sufficient funds are available and the amount is positive. It prints the updated balance or an error message if funds are insufficient.
#    - **`get_balance()`**: Returns the current balance, providing controlled access to the private `__balance` attribute.
#    - **`get_account_number()`**: Returns the account number, providing controlled access to the private `__account_number` attribute.
#
# 3. **Example Usage**:
#    - An instance of `BankAccount` is created with an initial balance.
#    - The deposit and withdrawal methods are called, demonstrating the encapsulated functionality.
#    - The balance and account number are accessed using the respective getter methods.
#
# ### Output
# When you run the code, you should see:
# ```
# Deposited: $500.00. New balance: $1500.00.
# Withdrew: $200.00. New balance: $1300.00.
# Current balance: $1300.00
# Account Number: 12345678
# Insufficient funds.
# ```
#
# This example demonstrates encapsulation by keeping sensitive data (like account balance and account number) private and providing public methods to interact with that data safely.

# %% [markdown]
# Q11) write a class that overrides the '__str__'and'__add__'magic methods. What will these methods allow you to do?
#
# A11) In Python, magic methods (also known as dunder methods, because they are surrounded by double underscores) allow you to define how objects of your class behave with built-in functions and operators. The `__str__` method is used to define a human-readable string representation of an object, while the `__add__` method allows you to define the behavior of the addition operator (`+`) for your class instances.
#
# Here's an example of a class called `Vector` that overrides the `__str__` and `__add__` magic methods:
#
# ### Code Example
#
# ```python
# class Vector:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
#     def __str__(self):
#         return f"Vector({self.x}, {self.y})"
#
#     def __add__(self, other):
#         if isinstance(other, Vector):
#             return Vector(self.x + other.x, self.y + other.y)
#         return NotImplemented
#
# # Example usage
# if __name__ == "__main__":
#     v1 = Vector(2, 3)
#     v2 = Vector(5, 7)
#
#     # Print the vectors
#     print(v1)  # Output: Vector(2, 3)
#     print(v2)  # Output: Vector(5, 7)
#
#     # Add the vectors
#     v3 = v1 + v2
#     print(v3)  # Output: Vector(7, 10)
# ```
#
# ### Explanation
#
# 1. **Class Definition (`Vector`)**:
#    - The `Vector` class has an `__init__` method that initializes two attributes, `x` and `y`, representing the components of the vector.
#
# 2. **Overriding `__str__`**:
#    - The `__str__` method is defined to return a string representation of the `Vector` instance in the format `Vector(x, y)`. This method is called when you use the `print()` function or `str()` on an instance of `Vector`.
#    - **Purpose**: This allows for a readable string representation of the object, making it easier to understand when printing the object.
#
# 3. **Overriding `__add__`**:
#    - The `__add__` method allows instances of the `Vector` class to be added together using the `+` operator. It checks if the other object being added is also a `Vector`. If so, it creates and returns a new `Vector` whose `x` and `y` components are the sums of the corresponding components of the two vectors.
#    - **Purpose**: This allows for intuitive addition of vector objects using the `+` operator.
#
# ### Example Usage
# - **Creating Vectors**: Two vectors `v1` and `v2` are created with components `(2, 3)` and `(5, 7)`, respectively.
# - **Printing Vectors**: When `print(v1)` or `print(v2)` is called, the `__str__` method is invoked, providing a readable format for the output.
# - **Adding Vectors**: The expression `v1 + v2` calls the `__add__` method, resulting in a new vector `v3` with components `(7, 10)`.
#
# ### Output
# When you run the code, you should see:
# ```
# Vector(2, 3)
# Vector(5, 7)
# Vector(7, 10)
# ```
#
# ### Summary
# By overriding the `__str__` method, you enhance the readability of your object instances, while overriding the `__add__` method allows you to define custom behavior for the addition operator, enabling intuitive arithmetic operations on your class instances.

# %% [markdown]
# Q12) Create a decorator that measures and prints the execution time of a function.
#
# A12) Creating a decorator in Python to measure and print the execution time of a function is a great way to enhance the functionality of existing functions without modifying their code. A decorator is a callable that takes another function as an argument and extends its behavior.
#
# Here's how you can create a `time_execution` decorator that measures the time a function takes to execute:
#
# ### Code Example
#
# ```python
# import time
#
# def time_execution(func):
#     def wrapper(*args, **kwargs):
#         start_time = time.time()  # Record the start time
#         result = func(*args, **kwargs)  # Call the original function
#         end_time = time.time()  # Record the end time
#         execution_time = end_time - start_time  # Calculate execution time
#         print(f"Execution time of '{func.__name__}': {execution_time:.4f} seconds")
#         return result  # Return the result of the original function
#     return wrapper
#
# # Example usage
# @time_execution
# def example_function(n):
#     total = 0
#     for i in range(n):
#         total += i
#     return total
#
# if __name__ == "__main__":
#     result = example_function(1000000)
#     print(f"Result: {result}")
# ```
#
# ### Explanation
#
# 1. **Importing Required Module**:
#    - The `time` module is imported to measure the time before and after the function execution.
#
# 2. **Decorator Definition (`time_execution`)**:
#    - The `time_execution` function is defined as a decorator that takes a function `func` as an argument.
#    - Inside it, a nested `wrapper` function is defined, which:
#      - Records the start time before calling the original function.
#      - Calls the original function using `func(*args, **kwargs)` to allow for any number of positional and keyword arguments.
#      - Records the end time after the function has executed.
#      - Calculates the execution time and prints it.
#      - Returns the result of the original function.
#
# 3. **Applying the Decorator**:
#    - The `@time_execution` syntax is used to apply the decorator to `example_function`.
#    - When `example_function` is called, it is wrapped in the `wrapper` function defined in the decorator.
#
# 4. **Example Usage**:
#    - In the `if __name__ == "__main__":` block, `example_function` is called with a large input (`1000000`), which sums the numbers from `0` to `n-1`.
#    - The execution time is printed alongside the result.
#
# ### Output
# When you run the code, you will see output similar to the following (the exact time may vary based on system performance):
#
# ```
# Execution time of 'example_function': 0.0687 seconds
# Result: 499999500000
# ```
#
# ### Summary
# This decorator allows you to measure and print the execution time of any function to which it is applied, making it a valuable tool for performance monitoring and optimization.

# %% [markdown]
# Q13) Explain the concept of the Diamond problem in multiple inheritance. How does python resolve it?
#
# A13) The **Diamond Problem** is a common issue that arises in programming languages that support multiple inheritance. It occurs when a class inherits from two classes (let's call them `B` and `C`), which both inherit from a single parent class (let's call it `A`). This creates a diamond-shaped hierarchy, hence the name.
#
# ### Diagram of the Diamond Problem
#
# ```
#       A
#      / \
#     B   C
#      \ /
#       D
# ```
#
# In this example:
# - Class `A` is the base class.
# - Classes `B` and `C` both inherit from class `A`.
# - Class `D` inherits from both `B` and `C`.
#
# ### The Problem
#
# The issue arises when class `D` calls a method that is defined in class `A`. Since both `B` and `C` inherit from `A`, the method resolution becomes ambiguous:
# - Which version of the method from class `A` should `D` inherit?
# - If `B` and `C` override the method from `A`, which implementation should be called?
#
# ### Python's Resolution Strategy: Method Resolution Order (MRO)
#
# Python uses a specific algorithm to resolve the Diamond Problem, which is defined by the **C3 linearization** algorithm. This ensures a consistent and predictable method resolution order (MRO).
#
# #### MRO in Python
#
# 1. **Depth-First Search**: Python follows a depth-first left-to-right search through the class hierarchy.
# 2. **Linearization**: The MRO is computed so that:
#    - Each class appears before its parents.
#    - If a class appears as a parent of multiple classes, it only appears once.
# 3. **No Conflicts**: The algorithm ensures that there are no conflicts, and it respects the order in which classes are defined.
#
# You can retrieve the MRO of a class using the `__mro__` attribute or the `mro()` method.
#
# ### Example
#
# Here's an example that demonstrates the Diamond Problem and how Python resolves it:
#
# ```python
# class A:
#     def show(self):
#         print("Method from class A")
#
# class B(A):
#     def show(self):
#         print("Method from class B")
#
# class C(A):
#     def show(self):
#         print("Method from class C")
#
# class D(B, C):
#     pass
#
# # Creating an instance of class D
# d = D()
# d.show()  # This will call the show() method from class B
#
# # Checking the MRO
# print(D.__mro__)  # Output: (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>)
# ```
#
# ### Explanation of the Example
#
# 1. **Class Definitions**:
#    - Class `A` has a method `show()`.
#    - Classes `B` and `C` override the `show()` method from `A`.
#    - Class `D` inherits from both `B` and `C`.
#
# 2. **Method Call**:
#    - When we create an instance of `D` and call `d.show()`, Python looks for the method `show()` in the following order according to the MRO: `D`, `B`, `C`, `A`.
#    - Since `B` is found first in the MRO, its implementation of `show()` is called.
#
# 3. **MRO Output**:
#    - The `print(D.__mro__)` statement shows the order of resolution: `D` → `B` → `C` → `A`.
#
# ### Conclusion
#
# The Diamond Problem highlights the potential complexities in multiple inheritance. Python’s use of the C3 linearization algorithm for MRO provides a clear and consistent way to resolve these ambiguities, ensuring that classes are initialized and methods are resolved in a predictable order.

# %% [markdown]
# Q14) write a class method that keeps track of the number of instances created from a class.
#
# A14) To create a class method that keeps track of the number of instances created from a class, you can use a class variable to maintain the count. A class method can be defined to access this class variable, allowing you to increment the count each time a new instance is created.
#
# Here's how you can implement this in Python:
#
# ### Code Example
#
# ```python
# class InstanceCounter:
#     # Class variable to keep track of the number of instances
#     instance_count = 0
#
#     def __init__(self):
#         # Increment the instance count each time a new instance is created
#         InstanceCounter.instance_count += 1
#
#     @classmethod
#     def get_instance_count(cls):
#         """Class method to return the current instance count."""
#         return cls.instance_count
#
# # Example usage
# if __name__ == "__main__":
#     obj1 = InstanceCounter()
#     obj2 = InstanceCounter()
#     obj3 = InstanceCounter()
#
#     print(f"Number of instances created: {InstanceCounter.get_instance_count()}")  # Output: 3
# ```
#
# ### Explanation
#
# 1. **Class Variable**:
#    - The class variable `instance_count` is defined at the class level (outside any methods). This variable will be shared among all instances of the class.
#
# 2. **Constructor (`__init__` method)**:
#    - The `__init__` method is called whenever a new instance of `InstanceCounter` is created. Inside this method, `InstanceCounter.instance_count` is incremented by 1.
#
# 3. **Class Method (`get_instance_count`)**:
#    - The `get_instance_count` method is defined as a class method using the `@classmethod` decorator. This method takes the class (`cls`) as its first argument and returns the current value of `instance_count`.
#    - You can call this method on the class itself or on any instance of the class.
#
# 4. **Example Usage**:
#    - In the `if __name__ == "__main__":` block, three instances of `InstanceCounter` are created.
#    - The `get_instance_count()` method is called on the class to retrieve the total number of instances created, which will output `3`.
#
# ### Output
# When you run the code, you will see:
# ```
# Number of instances created: 3
# ```
#
# ### Summary
# This example demonstrates how to use a class variable and a class method to keep track of the number of instances created from a class. This approach allows you to easily access and manage instance counts in a clean and organized manner.

# %% [markdown]
# Q15) Implement a static method in a class that checks if a given year is a leap year.
#
# A15) To implement a static method in a class that checks if a given year is a leap year, you can define the static method using the `@staticmethod` decorator. A leap year is defined as:
#
# 1. A year is a leap year if it is divisible by 4.
# 2. However, if the year is divisible by 100, it is not a leap year, unless:
# 3. The year is also divisible by 400, in which case it is a leap year.
#
# Here's how you can implement this in Python:
#
# ### Code Example
#
# ```python
# class YearChecker:
#     @staticmethod
#     def is_leap_year(year):
#         """Check if the given year is a leap year."""
#         if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#             return True
#         else:
#             return False
#
# # Example usage
# if __name__ == "__main__":
#     years_to_check = [2000, 2001, 1900, 2024, 2023]
#     for year in years_to_check:
#         if YearChecker.is_leap_year(year):
#             print(f"{year} is a leap year.")
#         else:
#             print(f"{year} is not a leap year.")
# ```
#
# ### Explanation
#
# 1. **Class Definition (`YearChecker`)**:
#    - The class `YearChecker` is defined to encapsulate the static method.
#
# 2. **Static Method (`is_leap_year`)**:
#    - The `is_leap_year` method is decorated with `@staticmethod`, which allows it to be called on the class itself without requiring an instance.
#    - The method takes one parameter, `year`, and checks if it meets the leap year conditions:
#      - If the year is divisible by 4 but not by 100, or if it is divisible by 400, the method returns `True` (indicating it is a leap year).
#      - Otherwise, it returns `False`.
#
# 3. **Example Usage**:
#    - In the `if __name__ == "__main__":` block, a list of years is defined to check.
#    - The program iterates over this list and calls the `is_leap_year` static method for each year, printing whether it is a leap year or not.
#
# ### Output
# When you run the code, you will see output like this:
#
# ```
# 2000 is a leap year.
# 2001 is not a leap year.
# 1900 is not a leap year.
# 2024 is a leap year.
# 2023 is not a leap year.
# ```
#
# ### Summary
# This example demonstrates how to define a static method in a class that checks if a given year is a leap year. Static methods are useful for utility functions that don't require access to instance or class-specific data.
